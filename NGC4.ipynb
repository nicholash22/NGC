# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_vector2d(vector2d, origin=[0, 0], **options):
    return plt.arrow(origin[0], origin[1], vector2d[0], vector2d[1],
              head_width=0.2, head_length=0.3, length_includes_head=True,
              **options)

# %%
#No 1
v_1 = np.array ([17,22,19])
v_1
# Out:
# array([17, 22, 19])

# %%
#No 2
A = np.array ([17,22,19])
B = np.array ([10,20,11])
C = np.array ([5,12,9])

# %%
v1 = A+B
v1
# Out:
# array([27, 42, 30])

# %%
v2 = B-C
v2
# Out:
# array([5, 8, 2])

# %%
v3 = A @ C
v3
# Out:
# 520

# %%
#norm A
np.linalg.norm(A)
# Out:
# 33.67491648096547

# %%
vec1 = A
vec2 = B

# %%
plot_vector2d(vec1, color='r')
plot_vector2d(vec2, color='g')
plt.axis([0,23,0,23]) #rentang axis x dan y
plt.axvline(0) #garis y = 0
plt.axhline(0) #garis x = 0
plt.grid()
plt.show()

# %%
plt.axis([0,7,0,7]) #rentang axis x dan y
plt.axvline(0) #garis y = 0
plt.axhline(0) #garis x = 0
plt.grid()
plt.show()
